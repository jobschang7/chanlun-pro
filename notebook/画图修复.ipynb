# %% [markdown]
# ## 画图不出，执行一下语句后，在返回之前的 tab，再次执行画图即可
#
# 确定当前环境是 jupyterlab，而不是 notebook
#
# 如果还不能解决，参照官方的方法尝试
#
# https://pyecharts.org/#/zh-cn/notebook?id=jupyter-lab

# %%
from pyecharts.globals import CurrentConfig, NotebookType

CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts.charts import Kline, Bar, Grid, Scatter, Line
from pyecharts import options as opts
from pyecharts.globals import ThemeType

Kline().load_javascript()
Bar().load_javascript()
Grid().load_javascript()
Scatter().load_javascript()
Line().load_javascript()

# %%
## 测试画图是否ok
line = (
    Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS))
        .add_xaxis(['衬衫', '羊毛衫', '雪绒衫', '裤子', '高跟鞋', '袜子'])
        .add_yaxis('商家A', [5, 20, 36, 10, 75, 90])
        .add_yaxis('商家B', [15, 6, 45, 20, 35, 66])
        .set_global_opts(title_opts=opts.TitleOpts(title='主标题', subtitle='副标题'))
)
line.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7ac9c03a0c12440380dd6e2bfa906b93" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_7ac9c03a0c12440380dd6e2bfa906b93 = echarts.init(
#             document.getElementById('7ac9c03a0c12440380dd6e2bfa906b93'), 'westeros', {renderer: 'canvas'});
#         var option_7ac9c03a0c12440380dd6e2bfa906b93 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     5
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     20
#                 ],
#                 [
#                     "\u96ea\u7ed2\u886b",
#                     36
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     10
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     75
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     90
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     15
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     6
#                 ],
#                 [
#                     "\u96ea\u7ed2\u886b",
#                     45
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     20
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     35
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     66
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7ed2\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e3b\u6807\u9898",
#             "target": "blank",
#             "subtext": "\u526f\u6807\u9898",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_7ac9c03a0c12440380dd6e2bfa906b93.setOption(option_7ac9c03a0c12440380dd6e2bfa906b93);
#     </script>
# </body>
# </html>
